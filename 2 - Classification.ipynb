# %%
import numpy as np
import pandas as pd

# %%
import pickle

PIK = "/content/drive/My Drive/dat/states.dat"
with open(PIK, "rb") as f:
    bert_en = pickle.load(f)

PIK = "/content/drive/My Drive/dat/tweetsEngTokCustom.dat"
with open(PIK, "rb") as f:
    custom_en = pickle.load(f)

PIK = "/content/drive/My Drive/dat/tweetsEngTokenized.dat"
with open(PIK, "rb") as f:
    nltk_en = pickle.load(f)

PIK = "/content/drive/My Drive/dat/MultilingualBertIt.dat"
with open(PIK, "rb") as f:
    bert_it = pickle.load(f)

PIK = "/content/drive/My Drive/dat/MultilingualBertItCustom.dat"
with open(PIK, "rb") as f:
    custom_it = pickle.load(f)

PIK = "/content/drive/My Drive/dat/MultilingualBertItNLTK.dat"
with open(PIK, "rb") as f:
    nltk_it = pickle.load(f)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
en = pd.read_csv("/content/drive/My Drive/dat/en_training.tsv",sep="\t")
it = pd.read_csv("/content/drive/My Drive/dat/it_training.tsv",sep="\t")

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# %%
X = custom_en[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = en["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
mlp = MLPClassifier() 

parameter_space = {
    'hidden_layer_sizes': [ (100,50),(200,100),(50,50)],  
   # 'activation': ['relu',"tanh"],
   # 'solver': ['adam', "sgd"], 
    'alpha': [0.01],
    'learning_rate': ['constant'],
}

clf = GridSearchCV(mlp, parameter_space, scoring="accuracy") #scoring da scegliere
clf.fit(X_train, y_train)

print('Best parameters found:\n', clf.best_params_)
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
# ...

# %%
print("Custom_en")
X = custom_en[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = en["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Custom_en
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.75      0.71      0.73      1883
#            1       0.62      0.66      0.64      1317
#
#     accuracy                           0.69      3200
#    macro avg       0.68      0.69      0.69      3200
# weighted avg       0.70      0.69      0.69      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       432
#            1       0.65      0.65      0.65       368
#
#     accuracy                           0.68       800
#    macro avg       0.68      0.68      0.68       800
# weighted avg       0.68      0.68      0.68       800

# %%
print("Bert eng")
X = bert_en[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = en["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,100), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Bert eng
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.74      0.83      0.78      1583
#            1       0.81      0.71      0.76      1617
#
#     accuracy                           0.77      3200
#    macro avg       0.77      0.77      0.77      3200
# weighted avg       0.78      0.77      0.77      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76       385
#            1       0.80      0.71      0.75       415
#
#     accuracy                           0.76       800
#    macro avg       0.76      0.76      0.76       800
# weighted avg       0.76      0.76      0.76       800

# %%
print("Nltk_en")
X = nltk_en[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = en["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.01, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Nltk_en
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.89      0.67      0.77      2355
#            1       0.46      0.77      0.57       845
#
#     accuracy                           0.70      3200
#    macro avg       0.67      0.72      0.67      3200
# weighted avg       0.78      0.70      0.72      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.87      0.62      0.72       605
#            1       0.38      0.71      0.49       195
#
#     accuracy                           0.64       800
#    macro avg       0.62      0.67      0.61       800
# weighted avg       0.75      0.64      0.67       800

# %%
print("Custom_it")
X = custom_it[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = it["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Custom_it
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.88      0.73      0.80      2097
#            1       0.61      0.81      0.70      1103
#
#     accuracy                           0.76      3200
#    macro avg       0.74      0.77      0.75      3200
# weighted avg       0.79      0.76      0.76      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73       513
#            1       0.55      0.72      0.63       287
#
#     accuracy                           0.69       800
#    macro avg       0.68      0.70      0.68       800
# weighted avg       0.72      0.69      0.69       800

# %%
print("Bert_it")
X = bert_it[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = it["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Bert_it
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79      1708
#            1       0.77      0.75      0.76      1492
#
#     accuracy                           0.78      3200
#    macro avg       0.78      0.77      0.78      3200
# weighted avg       0.78      0.78      0.78      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79       428
#            1       0.76      0.77      0.76       372
#
#     accuracy                           0.78       800
#    macro avg       0.78      0.78      0.78       800
# weighted avg       0.78      0.78      0.78       800

# %%
print("nltk_it")
X = nltk_it[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = it["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# nltk_it
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79      1774
#            1       0.74      0.75      0.74      1426
#
#     accuracy                           0.77      3200
#    macro avg       0.77      0.77      0.77      3200
# weighted avg       0.77      0.77      0.77      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       448
#            1       0.67      0.72      0.70       352
#
#     accuracy                           0.72       800
#    macro avg       0.72      0.72      0.72       800
# weighted avg       0.73      0.72      0.72       800

# %%
from sklearn.svm import SVC
print("custom_en SVC")
X = custom_en[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = en["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf=SVC()

clf.fit(X_train,y_train)
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# custom_en SVC
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.73      2385
#            1       0.40      0.69      0.50       815
#
#     accuracy                           0.65      3200
#    macro avg       0.63      0.67      0.62      3200
# weighted avg       0.74      0.65      0.68      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.84      0.61      0.71       586
#            1       0.39      0.67      0.49       214
#
#     accuracy                           0.63       800
#    macro avg       0.61      0.64      0.60       800
# weighted avg       0.72      0.63      0.65       800

# %%
from sklearn.svm import SVC
print("custom_it SVC")
X = custom_it[1].numpy() #custom_en, nlkt_en, bert_en... it...
y = it["misogynous"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf=SVC()

clf.fit(X_train,y_train)
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# custom_it SVC
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.87      0.68      0.76      2265
#            1       0.49      0.77      0.60       935
#
#     accuracy                           0.70      3200
#    macro avg       0.68      0.72      0.68      3200
# weighted avg       0.76      0.70      0.72      3200
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.86      0.63      0.73       572
#            1       0.45      0.74      0.56       228
#
#     accuracy                           0.67       800
#    macro avg       0.65      0.69      0.64       800
# weighted avg       0.74      0.67      0.68       800

# %%
import ktrain
from ktrain import text
import keras
from sklearn.model_selection import train_test_split

X = list(en["text"])
y = list(en["misogynous"])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


t = text.Transformer('bert-base-uncased', class_names=[0,1])
training = t.preprocess_train(X_train, y_train)
validation = t.preprocess_test(X_test, y_test)


model = t.get_classifier()
model.summary()
learner = ktrain.get_learner(model, train_data=training, val_data=validation, batch_size=64)
keras.utils.plot_model(model)

learner.fit(lr=10**-4, n_cycles=1, cycle_len=10, cycle_mult=1, lr_decay=0.9, early_stopping=1)

y_pred_validation = np.array(learner.predict(validation)[0, :, 1]>0.5, dtype='int')
y_pred_train = np.array(learner.predict(training)[0, :, 1]>0.5, dtype='int')

print('Accuracy train: {}'.format(accuracy_score(y_train, y_pred_train)))
print('F1 train: {}'.format(f1_score(y_train, y_pred_train)))
# Out:
# Using TensorFlow backend.
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 17
# 	95percentile : 27
# 	99percentile : 30
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 17
# 	95percentile : 28
# 	99percentile : 30
# Model: "tf_bert_for_sequence_classification"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# bert (TFBertMainLayer)       multiple                  109482240
# _________________________________________________________________
# dropout_37 (Dropout)         multiple                  0
# _________________________________________________________________
# classifier (Dense)           multiple                  1538
# ...
# Total params: 109,483,778
# Trainable params: 109,483,778
# Non-trainable params: 0
# _________________________________________________________________
# Train for 50 steps, validate for 25 steps
# Epoch 1/10
# ...

# %%
set(en[en["misogynous"]==1]["misogyny_category"])
# Out:
# {'derailing', 'discredit', 'dominance', 'sexual_harassment', 'stereotype'}

# %%
it["target"]= it["target"].replace("0","passive")
it["target"]= it["target"].replace("pass","passive")
set(it[it["misogynous"]==1]["target"])
# Out:
# {'active', 'passive'}

# %%
en_mys=en[en["misogynous"]==1]
it_mys=it[it["misogynous"]==1]

sum(it_mys["target"]=="active")
# Out:
# 1721

# %%
from sklearn import preprocessing


le = preprocessing.LabelEncoder()

le.fit(en_mys['misogyny_category'])
en_mys['misogyny_category']=le.transform(en_mys['misogyny_category'])

le.fit(en_mys['target'])
en_mys['target']=le.transform(en_mys['target'])

le.fit(it_mys['misogyny_category'])
it_mys['misogyny_category']=le.transform(it_mys['misogyny_category'])

it_mys['target']
le.fit(it_mys['target'])
it_mys['target']=le.transform(it_mys['target'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
print("target")
X = custom_en[1].numpy()[en["misogynous"]==1]
y = en_mys["target"]   #en, it...

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

mlp = MLPClassifier(hidden_layer_sizes=(200,150), activation="relu",alpha=0.05, learning_rate="constant", solver="adam", early_stopping=True)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# target
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84      1046
#            1       0.56      0.84      0.67       382
#
#     accuracy                           0.78      1428
#    macro avg       0.75      0.80      0.75      1428
# weighted avg       0.83      0.78      0.79      1428
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.79       263
#            1       0.48      0.79      0.60        94
#
#     accuracy                           0.72       357
#    macro avg       0.69      0.74      0.69       357
# weighted avg       0.79      0.72      0.74       357

# %%
set(en["misogyny_category"])
# Out:
# {'0', 'derailing', 'discredit', 'dominance', 'sexual_harassment', 'stereotype'}

# %%
sum(en["misogyny_category"]=="ster")
# Out:
# 0

# %%
from sklearn.neighbors import NearestCentroid

X = custom_en[1].numpy()[en["misogynous"]==1]
y = en_mys["misogyny_category"]   #en, it...

clf = NearestCentroid()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf.fit(X, y)

mlp.fit(X_train,y_train)
y_train_pred = mlp.predict(X_train)
y_test_pred = mlp.predict(X_test)
from sklearn.metrics import classification_report
print('Results on the train set:')
print(classification_report(y_train_pred, y_train))
print('Results on the test set:')
print(classification_report(y_test_pred, y_test))
# Out:
# Results on the train set:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.58      0.73      1428
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.58      1428
#    macro avg       0.20      0.12      0.15      1428
# weighted avg       1.00      0.58      0.73      1428
#
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.52      0.68       357
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.52       357
# ...

# %%
len(en.misogynous[:1759])
# Out:
# 1759

# %%
len(en[en["misogynous"]==1])
# Out:
# 1785
